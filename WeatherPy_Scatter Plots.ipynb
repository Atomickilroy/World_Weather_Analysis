# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

city_data = pd.read_csv("weather_data/cities.csv")
city_data_df = pd.DataFrame(city_data)
city_data_df.head()

# Extract relevant fields from the DataFrame for plotting.

lats = city_data_df["Lat"]

max_temps = city_data_df["Max Temp"]

humidity = city_data_df["Humidity"]

cloudiness = city_data_df["Cloudiness"]

wind_speed = city_data_df["Wind Speed"]

# Import Dependency time

import time

#Build the scatter plot for latitude vs max temp

plt.scatter(lats, 
            max_temps,
            edgecolor = "black",            
            linewidths = 1,marker ="o",
            alpha=0.8, label= "Cities",      
           )

# Incorporate the other graph properties

plt.title(f"City Latitude vs Max Temperature " + time.strftime(" %x "))

#x and y labels
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')

plt.legend

plt.grid(True)

plt.savefig("weather_data/Fig1.png")

#Show plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

city_data = pd.read_csv("weather_data/cities.csv")
city_data_df = pd.DataFrame(city_data)
city_data_df.head()

# Extract relevant fields from the DataFrame for plotting.

lats = city_data_df["Lat"]

max_temps = city_data_df["Max Temp"]

humidity = city_data_df["Humidity"]

cloudiness = city_data_df["Cloudiness"]

wind_speed = city_data_df["Wind Speed"]

# Import Dependency time

import time

#Build the scatter plot for latitude vs max temp

plt.scatter(lats, 
            humidity,
            edgecolor = "black",            
            linewidths = 1,marker ="o",
            alpha=0.8, label= "Cities",      
           )

# Incorporate the other graph properties

plt.title(f"City Latitude vs Humidity " + time.strftime(" %x "))

#x and y labels
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')

plt.legend

plt.grid(True)

plt.savefig("weather_data/Fig2.png")

#Show plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

city_data = pd.read_csv("weather_data/cities.csv")
city_data_df = pd.DataFrame(city_data)
city_data_df.head()

# Extract relevant fields from the DataFrame for plotting.

lats = city_data_df["Lat"]

max_temps = city_data_df["Max Temp"]

humidity = city_data_df["Humidity"]

cloudiness = city_data_df["Cloudiness"]

wind_speed = city_data_df["Wind Speed"]

# Import Dependency time

import time

#Build the scatter plot for latitude vs max temp

plt.scatter(lats, 
            cloudiness,
            edgecolor = "black",            
            linewidths = 1,marker ="o",
            alpha=0.8, label= "Cities",      
           )

# Incorporate the other graph properties

plt.title(f"City Latitude vs Cloudiness" + time.strftime(" %x "))

#x and y labels
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')

plt.legend

plt.grid(True)

plt.savefig("weather_data/Fig3.png")

#Show plot
plt.show()

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

city_data = pd.read_csv("weather_data/cities.csv")
city_data_df = pd.DataFrame(city_data)
city_data_df.head()

# Extract relevant fields from the DataFrame for plotting.

lats = city_data_df["Lat"]

max_temps = city_data_df["Max Temp"]

humidity = city_data_df["Humidity"]

cloudiness = city_data_df["Cloudiness"]

wind_speed = city_data_df["Wind Speed"]

# Import Dependency time

import time

#Build the scatter plot for latitude vs max temp

plt.scatter(lats, 
            wind_speed,
            edgecolor = "black",            
            linewidths = 1,marker ="o",
            alpha=0.8, label= "Cities",      
           )

# Incorporate the other graph properties

plt.title(f"City Latitude vs Wind Speed" + time.strftime(" %x "))

#x and y labels
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')

plt.legend

plt.grid(True)

plt.savefig("weather_data/Fig4.png")

#Show plot
plt.show()

# %%
#6.4.2 Find the Correlation Between lat and max temp

# %%
import numpy as np

# %%
    # Import linregress
    
from scipy.stats import linregress

#Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data

def plot_linear_regression(x_value,y_values_title,y_label,text_coordinates):


    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    
    plt.title(title)
    
    plt.xlabel('Latitude')
    
    plt.ylabel(y_label)
    
    plt.show()
# Out:
#   File "C:\Users\njliv\AppData\Local\Temp\ipykernel_21184\4055311924.py", line 12
#     (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
#     ^
# IndentationError: expected an indented block

# %%
#If we run this code there will be no output until we call the function with five parameters.
#To get an output from a function, we need to call the function with the correct number 
#of parameters or arguments for the function.

# %%
#Create a date frame for the Northern and Southern Hemispheres

city_data_df.head()
# Out:
#    City_ID          City Country                 Date      Lat       Lng  \
# 0        0       Tripoli      LY  2022-07-17 19:46:08  32.8752   13.1875
# 1        1  Kanadukathan      IN  2022-07-17 19:48:05  10.1754   78.7785
# 2        2          Hilo      US  2022-07-17 19:45:33  19.7297 -155.0900
# 3        3        Norden      DE  2022-07-17 19:43:57  53.6000    7.2000
# 4        4        Avarua      CK  2022-07-17 19:44:36 -21.2078 -159.7750
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     79.41        71           0       13.87
# 1     81.48        73         100        4.41
# 2     90.28        78          75        4.61
# 3     66.96        70          86        3.29
# 4     73.45        73          20        3.44

# %%
# Northern Hemisphere DF

index13 = city_data_df.loc[13]
index13
# Out:
# City_ID                        13
# City                 Punta Arenas
# Country                        CL
# Date          2022-07-17 19:48:09
# Lat                        -53.15
# Lng                      -70.9167
# Max Temp                    37.51
# Humidity                       81
# Cloudiness                      0
# Wind Speed                  26.46
# Name: 13, dtype: object

# %%
#We can also filter the data based on row value

city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 579     True
# 580     True
# 581    False
# 582    False
# 583     True
# Name: Lat, Length: 584, dtype: bool

# %%
#Combine the two methods

city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#    City_ID          City Country                 Date      Lat       Lng  \
# 0        0       Tripoli      LY  2022-07-17 19:46:08  32.8752   13.1875
# 1        1  Kanadukathan      IN  2022-07-17 19:48:05  10.1754   78.7785
# 2        2          Hilo      US  2022-07-17 19:45:33  19.7297 -155.0900
# 3        3        Norden      DE  2022-07-17 19:43:57  53.6000    7.2000
# 6        6      Victoria      HK  2022-07-17 19:43:54  22.2855  114.1577
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     79.41        71           0       13.87
# 1     81.48        73         100        4.41
# 2     90.28        78          75        4.61
# 3     66.96        70          86        3.29
# 6     86.38        82         100       13.00

# %%
#Create both df

northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
#Now we can perform linear regression on latitude and maximum temperature from each hemisphere DataFrame.

# %%
    # Import linregress
    
from scipy.stats import linregress

#Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data

def plot_linear_regression(x_values,y_values,title,y_label,text_coordinates):
    # Run regression on hemisphere weather data.
        (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
        regress_values = x_values * slope + intercept
    
    # Get the equation of the line.
        line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create a scatter plot and plot the regression line.
        plt.scatter(x_values,y_values)
        plt.plot(x_values,regress_values,"r")
    
    # Annotate the text for the line equation.
        plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    
        plt.title(title)
    
        plt.xlabel('Latitude')
    
        plt.ylabel(y_label)
    
        plt.show()

# %%
# Linear regression on the Northern Hemisphere

x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Call the function 

plot_linear_regression(x_values, y_values,
                      'Linear Regression on the Northern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(10,40))
print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=-0.5084709664097574, intercept=91.70015567332862, rvalue=-0.6724368776474671, pvalue=9.457570075320245e-55, stderr=0.02784494235263341, intercept_stderr=1.2276903504011285)

# %%
linregress(x_values,y_values)

# %%
# Linear regression on the Southern Hemisphere

x_values = southern_hemi_df["Lat"]

y_values = southern_hemi_df["Max Temp"]

# Call the function.

plot_linear_regression(x_values, y_values,
                       
                       'Linear Regression on the Southern Hemisphere \
                        for Maximum Temperature', 'Max Temp',(-50,90))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=0.8019722117163751, intercept=82.51343591158852, rvalue=0.7696769813142865, pvalue=3.8990047608137314e-36, stderr=0.05014298235733232, intercept_stderr=1.2748281677047824)

# %%
#The correlation between the latitude and the maximum temperature is
#strong to very strong because the r-value is less than –0.7 for the Northern Hemisphere 
#and greater than 0.7 for the Southern Hemisphere, as shown by the plots here. 
#This means that as we approach the equator, 0° latitude, the temperatures become warmer.
#And when we are further from the equator the temperatures become cooler.

# %%
#6.4.3 Humidity

# %%
# Linear regression on the Northern Hemisphere

x_values = northern_hemi_df["Lat"]

y_values = northern_hemi_df["Humidity"]

# Call the function.

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Humidity', '% Humidity',(40,10))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=0.07267502937980792, intercept=66.4844284395914, rvalue=0.06410940876855929, pvalue=0.19735899278752014, stderr=0.056283156261636734, intercept_stderr=2.4815381895015975)

# %%
# Linear regression on the Southern Hemisphere

x_values = southern_hemi_df["Lat"]

y_values = southern_hemi_df["Humidity"]

# Call the function.

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Humidity', '% Humidity',(-50,15))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=-0.09286407461642271, intercept=67.39605113485275, rvalue=-0.0629653423595049, pvalue=0.40373296389422486, stderr=0.11094997580608941, intercept_stderr=2.8207766613443974)

# %%
#The correlation between the latitude and percent humidity is very low because the r-value is less
#than 0.04 for the Northern and Southern Hemispheres for the plots shown here. 
#This means that percent humidity is unpredictable due to changing weather patterns that can increase
#or decrease percent humidity.

# %%
#6.4.4 Latitude and Percent Cloudiness

# %%
# Linear regression on the Northern Hemisphere

x_values = northern_hemi_df["Lat"]

y_values = northern_hemi_df["Cloudiness"]

# Call the function.

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(7,45))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=-0.028875545155472113, intercept=59.66218077441147, rvalue=-0.014829613987512081, pvalue=0.7657767843700402, stderr=0.09686388940103294, intercept_stderr=4.270752685136144)

# %%
# Linear regression on the Southern Hemisphere

x_values = southern_hemi_df["Lat"]

y_values = southern_hemi_df["Cloudiness"]

# Call the function.

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for % Cloudiness', '% Cloudiness',(-50,20))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=0.10667646248831561, intercept=48.278248962088014, rvalue=0.03717122810820324, pvalue=0.6222935501391913, stderr=0.2161748278101794, intercept_stderr=5.49599857617662)

# %%
#The correlation between the latitude and percent cloudiness is very low because the r-value is 
#less than –0.09 for the Northern Hemisphere and less than –0.02 for the Southern Hemisphere for the
#plots shown here. This means that cloudiness is unpredictable due to changing weather patterns that can 
#increase or decrease percent cloudiness.

# %%
#6.4.5 Latitude and Wind Speed

# %%
# Linear regression on the Northern Hemisphere

x_values = northern_hemi_df["Lat"]

y_values = northern_hemi_df["Wind Speed"]

# Call the function.

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \
                        for Wind Speed(mph)', 'Wind Speed (mph)',(35,30))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=-0.006668111947492399, intercept=8.308296479745536, rvalue=-0.023814458737219827, pvalue=0.6323395998657328, stderr=0.01392670253077972, intercept_stderr=0.6140317366585691)

# %%
# Linear regression on the Southern Hemisphere

x_values = southern_hemi_df["Lat"]

y_values = southern_hemi_df["Wind Speed"]

# Call the function.

plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \
                        for Wind Speed(mph)', 'Wind Speed (mph)',(-35,20))

print(linregress(x_values,y_values))
# Out:
# LinregressResult(slope=-0.1081426650418257, intercept=6.323106568617927, rvalue=-0.25986051704026986, pvalue=0.00046018918674472906, stderr=0.03029133785728903, intercept_stderr=0.7701227354756152)

# %%
#The correlation between the latitude and wind speed is very low because the r-value is less
#than –0.07 for the Northern Hemisphere and less than –0.3 for the Southern Hemisphere for the 
#plots shown here. This means that wind speed is unpredictable due to changing weather patterns 
#that can increase or decrease wind speed.
